# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranalideokate/house-price-prediction/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as nm
import matplotlib.pyplot as mtp
import pandas as pd

# %%
pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=366b965b8366b1b15bfa29dcab55f4628fe90d9dde1768aca8b8417354678b9a
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
dataset=pd.read_csv('Grocery Products Purchase.csv')
transactions=[]
for i in range(0,7501):
  transactions.append([str(dataset.values[i,j]) for j in range(0,5)])

# %%
from apyori import apriori
rules=apriori(transactions=transactions,min_support=0.003,min_confidence=0.2,min_length=2,max_length=2)

# %%
results=list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'nan'}), support=0.6205839221437142, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'nan'}), confidence=0.6205839221437142, lift=1.0)]),
#  RelationRecord(items=frozenset({'whole milk'}), support=0.23890147980269297, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'whole milk'}), confidence=0.23890147980269297, lift=1.0)]),
#  RelationRecord(items=frozenset({'nan', 'UHT-milk'}), support=0.009198773496867084, ordered_statistics=[OrderedStatistic(items_base=frozenset({'UHT-milk'}), items_add=frozenset({'nan'}), confidence=0.3150684931506849, lift=0.5076968350425967)]),
#  RelationRecord(items=frozenset({'nan', 'beef'}), support=0.014131449140114652, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beef'}), items_add=frozenset({'nan'}), confidence=0.2789473684210526, lift=0.4494917745491548)]),
# ...

# %%
for item in results:  
    pair = item[0]   
    items = [x for x in pair]   
  
    print("Support: " + str(item[1]))  
    print("Confidence: " + str(item[2][0][2]))  
    print("Lift: " + str(item[2][0][3]))  
    print("=============================================")
# Out:
# Support: 0.6205839221437142
# Confidence: 0.6205839221437142
# Lift: 1.0
# ...
# Support: 0.23890147980269297
# Confidence: 0.23890147980269297
# Lift: 1.0
# ...
# Support: 0.009198773496867084
# Confidence: 0.3150684931506849
# Lift: 0.5076968350425967
# ...
# Support: 0.014131449140114652
# Confidence: 0.2789473684210526
# Lift: 0.4494917745491548
# ...
# Support: 0.014798026929742702
# Confidence: 0.29210526315789476
# Lift: 1.5969982353843795
# ...
# Support: 0.01559792027729636
# Confidence: 0.3078947368421053
# Lift: 2.8761126040505998
# ...
# Support: 0.014664711371817091
# Confidence: 0.2894736842105263
# Lift: 1.211686442669173
# ...
# Support: 0.006932409012131715
# Confidence: 0.22608695652173913
# Lift: 0.36431326764115257
# ...
# Support: 0.008132249033462205
# Confidence: 0.26521739130434785
# Lift: 1.449996831030549
# ...
# Support: 0.006265831222503666
# Confidence: 0.20434782608695654
# Lift: 1.955118677905945
# ...
# Support: 0.007598986801759766
# Confidence: 0.24782608695652175
# Lift: 1.0373568517080747
# ...

# %% [markdown]
# From the above output, we can analyze each rule. The first rules, which is Light cream → chicken, states that the light cream and chicken are bought frequently by most of the customers. The support for this rule is 0.0045, and the confidence is 29%. Hence, if a customer buys light cream, it is 29% chances that he also buys chicken, and it is .0045 times appeared in the transactions. We can check all these things in other rules also.
